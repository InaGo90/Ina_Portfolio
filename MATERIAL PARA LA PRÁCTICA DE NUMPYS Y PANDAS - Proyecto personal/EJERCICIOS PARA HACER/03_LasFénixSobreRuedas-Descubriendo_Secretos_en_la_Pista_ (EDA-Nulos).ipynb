# %% [markdown]
# ## Las Fénix Sobre Ruedas - Misión 03: Descubriendo Secretos en la Pista (EDA y Nulos)

# %% [markdown]
# # 📝
#
# **DE:** Isabel "La Centella" Montero
#
# **PARA:** Nuestra Analista de Élite
#
# **ASUNTO:** ¡Quiero Rayos X para estos Datos!
#
# Analista, el orden que pusiste con Pandas en la misión anterior ha sido útil. Pero ahora quiero más. Necesito que te metas hasta la cocina de los datos. Esto que llamáis **Análisis Exploratorio de Datos (EDA)**.
#
# Quiero que uses ese "olfato" de analista para:
# 1.  **Entender a fondo cada variable**: ¿Qué tenemos exactamente? ¿Numéricas, categóricas? ¿Qué valores únicos hay?
# 2.  **Limpiar lo que quede**: Busca y elimina filas duplicadas si las hay. Y muy importante, gestiona esos molestos **valores nulos**. ¡No quiero agujeros en mi información!
# 3.  **Describir lo que ves**: Dame un resumen estadístico de las métricas clave.
# 4.  **Primeras pistas**: ¿Hay alguna patinadora que destaque consistentemente? ¿Alguna relación obvia entre, por ejemplo, las horas de sueño y el rendimiento?
#
# Básicamente, quiero que me ayudes a ver patrones, detectar anomalías y, si hay suerte, encontrar alguna ventaja oculta o problema que no estemos viendo. ¡Manos a la obra!
#
# ---
# La Centella 🌪️

# %%
#importa pandas
#importa numpy

# Cargar el CSV procesado del Notebook 02
# Visualizar las primeras filas para confirmar carga y nuevas columnas

# %% [markdown]
# ### Paso 1: Entendimiento General y Tipos de Datos 🔍
#
# Antes de sumergirnos, "La Centella" quiere una ficha técnica actualizada. Vamos a verificar la estructura y los tipos de datos de nuestras columnas después de los procesos anteriores.
#
# **Tu tarea:**
# * Muestra la información general del DataFrame (`.info()`) para ver tipos de datos y un primer conteo de nulos.
# * Usa `.select_dtypes()` para separar mentalmente (o en variables si quieres) las columnas numéricas de las categóricas (tipo 'object').
# * Muestra los nombres de todas las columnas (`.columns`).

# %%
""" Código de Entendimiento General """
# Out:
# ' Código de Entendimiento General '

# %% [markdown]
# ### Paso 2: Explorando las Variables Categóricas 🏷️
#
# Para las variables que no son números (categóricas), "La Centella" quiere saber qué opciones hay.
#
# **Tu tarea:**
# Para cada una de las siguientes columnas categóricas (o las que consideres más relevantes): `Alias_Patinadora`, `Tipo_Sesion`, `Equipamiento_Principal_Test`, `Lesion_Reportada_S_N`, `Zona_Entrenamiento_Codigo`:
# * Obtén los valores únicos con `.unique()`.
# * Cuenta la frecuencia de cada valor único con `.value_counts()`.
#     Esto nos ayuda a entender la distribución de estas categorías.

# %%
"""Código de Análisis Categórico"""
# Out:
# 'Código de Análisis Categórico'

# %% [markdown]
# ### Paso 3: Resumen Estadístico de Variables Numéricas 📊
#
# "La Centella" quiere cifras concretas para las métricas de rendimiento. Un resumen estadístico es clave.
#
# **Tu tarea:**
# * Utiliza `.describe()` sobre el DataFrame completo. Pandas inteligentemente solo aplicará esto a las columnas numéricas.
# * Presta atención a:
#     * `count`: para ver si hay diferencia con el total de filas (indicando nulos pre-tratamiento).
#     * `mean` (media) y `50%` (mediana): para entender la tendencia central.
#     * `std` (desviación estándar): para la dispersión de los datos.
#     * `min` y `max`: para conocer el rango.
#     * `25%`, `75%` (percentiles): para entender la distribución.
# * Interpreta brevemente algún hallazgo (ej. "¿La duración media de sesión es la esperada? ¿Hay mucha variación en las puntuaciones?").

# %%
"""Código de Análisis Numérico"""
# Out:
# 'Código de Análisis Numérico'

# %% [markdown]
# ### Paso 4: Identificación y Gestión de Filas Duplicadas 🗑️
#
# No queremos que datos repetidos distorsionen nuestros análisis.
#
# **Tu tarea:**
# * Verifica si existen filas completamente duplicadas en el DataFrame usando `.duplicated().sum()`.
# * Si encuentras duplicados, elimínalos, conservando la primera aparición (`keep='first'`). Muestra cuántas filas había antes y después.
# * **Importante**: Realiza esta operación sobre `df_eda` para que los cambios persistan.

# %%
""" Código de Gestión de Duplicados """
# Out:
# ' Código de Gestión de Duplicados '

# %% [markdown]
# ### Paso 5: Profundizando en los Valores Nulos 🕳️
#
# Los valores nulos (o *missing values*) pueden distorsionar nuestros análisis si no los tratamos adecuadamente.  "La Centella" quiere saber dónde falta información y qué haremos al respecto.
#
# **Tu tarea:**
# 1.  Calcula el número total de valores nulos por columna usando `.isnull().sum()`.
# 2.  Calcula el porcentaje de valores nulos por columna.
# 3.  Para las columnas identificadas en la Misión 01 (`Duracion_Min`, `Pulsaciones_Max_BPM`, etc.) que ya limpiamos y donde los errores se convirtieron a `NaN`, verifica su estado actual.
# 4.  **Estrategia de imputación simple (según tus apuntes, la imputación es una técnica de EDA ):**
#     * Para columnas **numéricas** con un porcentaje bajo de nulos (ej. < 5-10%), puedes imputar los `NaN` con la **media** o **mediana** de la columna. Justifica tu elección (mediana es más robusta a outliers).
#     * Para columnas **categóricas** con pocos nulos, puedes imputar con la **moda** (el valor más frecuente) o con un string como "Desconocido".
#     * Si una columna tiene un porcentaje muy alto de nulos, podríamos considerar eliminarla en el futuro, pero por ahora, la dejaremos y solo anotaremos el problema.
# 5.  Aplica tus decisiones de imputación y verifica que los nulos se hayan reducido.
#     * **Importante**: Realiza esta operación sobre `df_eda`.

# %%
"""Código de Gestión de Nulos"""
# Out:
# 'Código de Gestión de Nulos'

# %% [markdown]
# ### Paso 6: Buscando las Primeras Pistas - Relaciones entre Variables
#
# "La Centella" quiere empezar a ver cómo se relacionan las cosas.
#
# **Tu tarea (simplificada para este notebook):**
# 1.  **Agrupación:** Agrupa los datos por `Alias_Patinadora` y calcula la media de `Puntuacion_Rendimiento` para cada una. ¿Quiénes tienen las medias más altas y más bajas? (`.groupby()`)
# 2.  **Correlación:** Calcula la matriz de correlación para las principales variables numéricas (ej. `Duracion_Min`, `Pulsaciones_Max_BPM`, `Puntuacion_Rendimiento`, `Horas_Sueño_Previas`, `Faltas_Totales`). ¿Observas alguna correlación fuerte (cercana a 1 o -1) que te llame la atención? (`.corr()`)

# %%
""" Código de Análisis de Relaciones """
# Out:
# ' Código de Análisis de Relaciones '

# %% [markdown]
# ### 🎯 Misión 03: ¡Primeros Descubrimientos! 💪
#
# ¡Excelente trabajo de exploración, analista!
#
# Con este EDA, "La Centella" tiene una visión mucho más clara de:
#
# * Las características de cada variable.
# * La calidad de los datos (duplicados eliminados, nulos gestionados).
# * Un resumen estadístico que define el "estado general" del equipo.
# * Las primeras pistas sobre qué patinadoras están destacando y cómo algunas variables podrían estar interconectadas.
#
# Hemos sentado las bases para análisis más profundos y, crucialmente, para la visualización de datos, donde realmente podremos "ver" estas historias.
#
# **Tu tarea final para esta misión:**
# * Guarda tu DataFrame procesado en un nuevo archivo CSV llamado `rendimiento_fenix_eda_limpio.csv`. Este será el insumo para la próxima misión, donde probablemente visualizaremos estos hallazgos.
#
# 🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥

# %%
# Guardar el DataFrame para el siguiente notebook
# Out:
# 'try:\n    df_eda.to_csv(\'rendimiento_fenix_eda_limpio.csv\', sep=\';\', index=False)\n    print("\nDataFrame guardado exitosamente como \'rendimiento_fenix_eda_limpio.csv\'")\nexcept Exception as e:\n    print(f"Error al guardar el DataFrame: {e}")'
